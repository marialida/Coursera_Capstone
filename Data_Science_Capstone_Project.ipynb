# %% [markdown]
# This is my final project for my Data Science Certification with IBM - Coursera.
# The case study is as follows:
#
# Case Study:
# - You live on the west side of the city of Toronto in Canada.
# - You love your neighbourhood, mainly because of all the great amenities and other types of venues that exist in the neighbourhood, such as gourmet fast food joints, pharmacies, parks, grad schools and so on.
# - You receive a job offer
#    - from a great company on the other side of the city
#    - with great career prospects
#    - You, unfortunately, must move if you decide to accept the offer.
#
# **YOU NEED TO**: determine neighbourhoods on the other side of the city that are exactly the same as your current neighbourhood, and if not perhaps similar neighbourhoods that are at least closer to your new job.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
